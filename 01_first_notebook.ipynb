# %%
print("Hello, Data Analysis!")
# Out:
# Hello, Data Analysis!

# %%
sales = [100, 250, 180, 320, 450]

sum(sales)
# Out:
# 1300

# %%
account_balance = 2500000
deposit = 500000

new_balance = account_balance + deposit

print("new balance is", new_balance)
# Out:
# new balance is 3000000

# %%
customer = "John"
age = 34
balance = 2500000
active = True
print(type(customer))
print(type(age))
print(type(balance))
print(type(active))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %%
customer_name = "Sarah"
age = 29
balance = 1750000
interest_rate = 8.5
active_customer = True

print(customer_name)
print(age)
print(balance)
print(interest_rate)
print(active_customer)
# Out:
# Sarah
# 29
# 1750000
# 8.5
# True

# %%
balance = 1750000
deposit = 500000
withdrawal = 250000
final_balance = balance + deposit - withdrawal
print(final_balance)
# Out:
# 2000000

# %%
customers = ["Sarah", "John", "David", "Peter"]

print(customers)
# Out:
# ['Sarah', 'John', 'David', 'Peter']

# %%
print(len(customers))
# Out:
# 4

# %%
balances = [1750000, 800000, 3200000, 450000]

print(balances)
print(len(balances))
print(balances[0])
# Out:
# [1750000, 800000, 3200000, 450000]
# 4
# 1750000

# %%
print(balances[1])
print(balances[2])
print(balances[3])
# Out:
# 800000
# 3200000
# 450000

# %%
print(balances[-1])
# Out:
# 450000

# %%
balances[3]=600000
print(balances[3])
print(balances)
# Out:
# 600000
# [1750000, 800000, 3200000, 600000]

# %%
balances.append(950000)
print(balances)
# Out:
# [1750000, 800000, 3200000, 600000, 950000]

# %%
balances.pop()
print(balances)
# Out:
# [1750000, 800000, 3200000, 600000]

# %%
balances[3]=600000
balances.append(950000)
print(balances)
# Out:
# [1750000, 800000, 3200000, 600000, 950000]

# %%
balances.pop(-1)
print(balances)
# Out:
# [1750000, 800000, 3200000, 600000]

# %%
customer = {
    "name": "Sarah",
    "age": 29,
    "balance": 1750000,
    "active": True
}
print(customer['name'])
# Out:
# Sarah

# %%
exercise = {
    'Name': 'John',
    'Age': 35,
    'Balance': 2500000,
    'Active': True
}

print(exercise ['Name'])
print(exercise['Age'])
print(exercise['Balance'])
print(exercise['Active'])
exercise['Balance']=3000000
print(exercise['Balance'])
# Out:
# John
# 35
# 2500000
# True
# 3000000

# %%
customers = [
    {
        "name": "Sarah",
        "age": 29,
        "balance": 1750000
    },
    {
        "name": "John",
        "age": 35,
        "balance": 3000000
    },
    {
        "name": "David",
        "age": 42,
        "balance": 4500000
    }
]
print(customers)
print(customers[0])
print(customers[0]['age'])
# Out:
# [{'name': 'Sarah', 'age': 29, 'balance': 1750000}, {'name': 'John', 'age': 35, 'balance': 3000000}, {'name': 'David', 'age': 42, 'balance': 4500000}]
# {'name': 'Sarah', 'age': 29, 'balance': 1750000}
# 29

# %%
for customer in customers:
    print(customer["name"])
# Out:
# Sarah
# John
# David

# %%
total_balance = 0
for customer in customers:
    total_balance=total_balance+customer['balance']
print(total_balance)
# Out:
# 9250000

# %%
for customer in customers:
    print(customer['name'])
# Out:
# Sarah
# John
# David

# %%
for customer in customers:
    print(customer['name'], customer['balance'])
# Out:
# Sarah 1750000
# John 3000000
# David 4500000

# %%
total_balance=0
for customer in customers:
    total_balance+=customer['balance']
print(total_balance)
# Out:
# 9250000

# %%
age = 25

if age >= 18:
    print("Adult")
# Out:
# Adult

# %%
for customer in customers:
    if customer['balance'] > 3000000:
        print(customer['name'])
print('||')
for customer in customers:
    if customer['age'] > 10:
        print(customer['name'])
print('||')
for customer in customers:
    if customer['balance'] > 200000:
        print(customer['name'], customer['balance'])
# Out:
# David
# ||
# Sarah
# John
# David
# ||
# Sarah 1750000
# John 3000000
# David 4500000

# %%
for customer in customers:

    if customer["balance"] > 3000000:
        print(customer["name"], "High balance")

    elif customer["balance"] >= 1000000:
        print(customer["name"], "Medium balance")

    else:
        print(customer["name"], "Low balance")
# Out:
# Sarah Medium balance
# John Medium balance
# David High balance

# %%
for customer in customers:
    if customer['balance'] > 4000000:
        print(customer['name'], 'VIP')
    elif customer['balance'] >= 1000000:
        print(customer['name'],   'Regular')
    else:
        print(customer['name'], 'Low')
# Out:
# Sarah Regular
# John Regular
# David VIP

# %%
customers = [
    {
        "name": "Sarah",
        "age": 29,
        "balance": 1750000
    },
    {
        "name": "John",
        "age": 35,
        "balance": 3000000
    },
    {
        "name": "David",
        "age": 42,
        "balance": 4500000
    }
]
for customer in customers:
    if customer['age'] > 30 and customer['balance'] > 2000000:
     print(customer['name'])
# Out:
# John
# David

# %%
customers = [
    {
        "name": "Sarah",
        "age": 29,
        "balance": 1750000
    },
    {
        "name": "John",
        "age": 35,
        "balance": 3000000
    },
    {
        "name": "David",
        "age": 42,
        "balance": 4500000
    }
]
for customer in customers:
    if customer['age'] < 30 or customer['balance'] > 4000000:
     print(customer['name'])
# Out:
# Sarah
# David

# %%
def avg(number1,number2,number3):
    avg=(number1+number2+number3)/3
    return avg
result =avg(100, 200, 300)
print(result)
# Out:
# 200.0

# %%
customer_balance =0

for customer in customers:
    customer_balance+=customer['balance']
    average_balance = customer_balance/len(customers)
print('average balance is', average_balance)
# Out:
# average balance is 3083333.3333333335

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for number in range(2,7):
    print(number)
for number in range(2,20,2):

    print(number)
# Out:
# 2
# 3
# 4
# 5
# 6
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
for i in range(len(customers)):
    print(customers[i]['name'])
# Out:
# Sarah
# John
# David

# %%
for i in range(len(customers)):
    print(f"Customer {i}: {customers[i]['name']}")
# Out:
# Customer 0: Sarah
# Customer 1: John
# Customer 2: David

# %%
for i in range(len(customers)):
    print(f"Customer {i} is {customers[i]['name']} and has a balance of {customers[i]['balance']}")
# Out:
# Customer 0 is Sarah and has a balance of 1750000
# Customer 1 is John and has a balance of 3000000
# Customer 2 is David and has a balance of 4500000

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python314\python.exe

# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
# ...

# %%
import numpy as np

print(np.__version__)
