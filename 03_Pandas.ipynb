# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %%
data = {
    "Name": ["Sarah", "John", "David", "Mary", "Peter","Mulongo"],
    "Age": [29, 35, 42, 31, 27, 31],
    "Balance": [1750000, 3000000, 4500000, 2200000, 850000, 5000000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age  Balance
# 0    Sarah   29  1750000
# 1     John   35  3000000
# 2    David   42  4500000
# 3     Mary   31  2200000
# 4    Peter   27   850000
# 5  Mulongo   31  5000000

# %%
#for professional data received

# %%
print(df.head()) #what did i receive- first 5 rows printed
# Out:
#     Name  Age  Balance
# 0  Sarah   29  1750000
# 1   John   35  3000000
# 2  David   42  4500000
# 3   Mary   31  2200000
# 4  Peter   27   850000

# %%
print(df.shape) #how large is it - dimensions
# Out:
# (6, 3)

# %%
print(df.info()) #what does it look like
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     6 non-null      str
#  1   Age      6 non-null      int64
#  2   Balance  6 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 276.0 bytes
# None

# %%
print(df.describe()) #does anything look wrong
# Out:
#              Age       Balance
# count   6.000000  6.000000e+00
# mean   32.500000  2.883333e+06
# std     5.357238  1.612038e+06
# min    27.000000  8.500000e+05
# 25%    29.500000  1.862500e+06
# 50%    31.000000  2.600000e+06
# 75%    34.000000  4.125000e+06
# max    42.000000  5.000000e+06

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Balance'], dtype='str')

# %%
#print(df['Name'])
#print(df['Age'])
print(df[['Name','Age']])
# Out:
#       Name  Age
# 0    Sarah   29
# 1     John   35
# 2    David   42
# 3     Mary   31
# 4    Peter   27
# 5  Mulongo   31

# %%
print(df.iloc[[1,4]]) #select specific row
# Out:
#     Name  Age  Balance
# 1   John   35  3000000
# 4  Peter   27   850000

# %%
print(df.iloc[2]["Balance"]) #selects specific value
# Out:
# 4500000

# %%
print(df.iloc[3]['Balance'])
# Out:
# 2200000

# %%
print(df[df['Balance'] > 2000000])
# Out:
#       Name  Age  Balance
# 1     John   35  3000000
# 2    David   42  4500000
# 3     Mary   31  2200000
# 5  Mulongo   31  5000000

# %%
print(df[(df["Balance"] >= 1000000) & (df["Balance"] <= 4000000)])
# Out:
#     Name  Age  Balance
# 0  Sarah   29  1750000
# 1   John   35  3000000
# 3   Mary   31  2200000
